# %%
# Import necessary packages
import os 
import random 
import string 
import nipype.interfaces.io as nio 
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util 
import matplotlib.pylab as plt 
import nibabel as nb
import numpy as np 

from os.path import abspath 
from nipype import Workflow, Node, MapNode, Function 
from nipype.interfaces.fsl import ExtractROI, BET, GLM, Threshold, ErodeImage, ApplyMask
from nipype.interfaces.spm import SliceTiming, Realign, Coregister, Normalize, Smooth, Segment, ApplyTransform
from nipype.interfaces.spm.utils import Reslice
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.base import Undefined
from nipype.utils.filemanip import filename_to_list
from nilearn.plotting import plot_anat
from nipype.interfaces import IdentityInterface
from nipype.algorithms.confounds import CompCor, ACompCor
from nilearn.signal import clean 
from functions import bandpass_filter, Design_Matrix, Motion_reg_creator, QC, roi_t_extract

# %% [markdown]
# ## Initialization

# %%
# Initialize paths and parameters here 

# Main directory of the data 
data_dir = "/home/sepehr/Desktop/T1_pipeline"

# Main directory to save results 
out_dir = "/home/sepehr/Desktop/T1_pipeline/preproc"

# SPM and FSL main directories
SPM_dir = '/home/sepehr/My_Documents/Softwares/SPM/spm12'
FSL_dir = '/usr/local/fsl'

# fMRI acquisition parameters
Num_of_Slices = 32 
TR = 2
TA = TR - TR/float(Num_of_Slices)

# List of subjects to apply pipeline on  
subject_list = ['s2']

# %% [markdown]
# ## Data Reading

# %%
# Reading subjects' structural and functional data (data should be stored properly)
info = dict(
    func=[['subject_id', 'func']],
    struct=[['subject_id', 'struct']])
infosource = Node(
    interface=util.IdentityInterface(fields=['subject_id']), name="infosource")
infosource.iterables = ('subject_id', subject_list)
datasource = Node(interface=nio.DataGrabber(
                     infields=['subject_id'], outfields=['func', 'struct']),
                     name='datasource')
datasource.inputs.base_directory = data_dir
datasource.inputs.template = '%s/%s.nii'
datasource.inputs.template_args = info
datasource.inputs.sort_filelist = True

# Reading necessary files for the pipeline 
# Before that, you should give full permission to the fsl folder (sudo chmod -R a+rwx /path/to/fsl)
gm_prob = SPM_dir + '/toolbox/OldSeg/grey.nii'
wm_prob = SPM_dir + '/toolbox/OldSeg/white.nii'
csf_prob = SPM_dir + '/toolbox/OldSeg/csf.nii'
MNI_template_comp = FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii.gz'
sig = nb.load(MNI_template_comp)
nb.save(sig, FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii')
MNI_template = FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii'
atlas = '/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Atlas_files/Schaefer_100par_7net_2mm/atlas.nii'

# %% [markdown]
# ## Preprocessing Pipeline Nodes Definition

# %%
# Initial Volume Removal 
num_of_scans_rmv = 3
VolRv = Node(ExtractROI(t_min=num_of_scans_rmv, t_size=-1, output_type='NIFTI'),
               name="VolumeRemoval")

# Slice Time Correction 
SliceTimeCorr = Node(SliceTiming(), name="SliceTimeCorrection")
SliceTimeCorr.inputs.num_slices = Num_of_Slices  
SliceTimeCorr.inputs.time_repetition = TR 
SliceTimeCorr.inputs.time_acquisition = TA 
SliceTimeCorr.inputs.slice_order = list(range(1,Num_of_Slices+1))
SliceTimeCorr.inputs.ref_slice = 1 

# Realignment of functional data 
ReAlign = Node(Realign(), name="Realignment")
ReAlign.inputs.quality = 0.9
ReAlign.inputs.fwhm = 5
ReAlign.inputs.separation = 4 
ReAlign.inputs.register_to_mean = True 
ReAlign.inputs.interp = 2
ReAlign.inputs.write_interp = 4
ReAlign.inputs.write_mask = True 

# ART Artifact Detection 
Art = Node(ArtifactDetect(), name="ArtifactDetection")
Art.inputs.parameter_source = 'SPM'
Art.inputs.use_norm = Undefined
Art.inputs.rotation_threshold = 0.05
Art.inputs.translation_threshold = 3 
Art.inputs.zintensity_threshold = 3
Art.inputs.mask_type = 'spm_global'
Art.inputs.save_plot = True 

# Coregistration of functional data to structural data in native space 
CoReg = Node(Coregister(), name='Coregistration')
CoReg.inputs.cost_function = 'nmi'
CoReg.inputs.separation = [4, 2]
CoReg.inputs.tolerance = [0.02, 0.02, 0.02, 
                          0.001, 0.001, 0.001, 
                          0.01, 0.01, 0.01, 
                          0.001, 0.001, 0.001]

# Brain Extraction 
Bet = Node(BET(), name='BrainExtraction')
Bet.inputs.mask = True 
Bet.inputs.frac = 0.3 
Bet.inputs.output_type = 'NIFTI'

# Segmentation of Structural Data 
Seg = Node(Segment(), name='Segmentation')
Seg.inputs.gm_output_type = [False, False, True] #Native space 
Seg.inputs.wm_output_type = [False, False, True] #Native space
Seg.inputs.csf_output_type = [False, False, True] #Native space 
Seg.inputs.save_bias_corrected = True 
Seg.inputs.clean_masks = 'no'
Seg.inputs.tissue_prob_maps=[gm_prob, wm_prob, csf_prob]
Seg.inputs.gaussians_per_class = [2, 2, 2, 4]
Seg.inputs.affine_regularization = 'mni' 
Seg.inputs.warping_regularization = 1 
Seg.inputs.warp_frequency_cutoff = 25 
Seg.inputs.bias_regularization = 0.0001
Seg.inputs.bias_fwhm = 60 
Seg.inputs.sampling_distance = 3 

# Thresholding Probability Maps to Create Binary Masks 
gmth = Node(Threshold(), name='GMBinaryMask')
gmth.inputs.thresh = 0.5 
gmth.inputs.args = '-bin'
gmth.inputs.output_type = 'NIFTI'

wmth = Node(Threshold(), name='WMBinaryMask')
wmth.inputs.thresh = 0.5 
wmth.inputs.args = '-bin'
wmth.inputs.output_type = 'NIFTI'

csfth = Node(Threshold(), name='CSFBinaryMask')
csfth.inputs.thresh = 0.5 
csfth.inputs.args = '-bin'
csfth.inputs.output_type = 'NIFTI'

# Erosion of WM Mask 
erwm = Node(ErodeImage(), name='ErosionWM')
erwm.inputs.kernel_shape = '3D'
erwm.inputs.output_type = 'NIFTI'

# Erosion of CSF Mask 
ercsf = Node(ErodeImage(), name='ErosionCSF')
ercsf.inputs.kernel_shape = '3D'
ercsf.inputs.output_type = 'NIFTI'

# Normalization of Structural and Functional Image to MNI Space 
Norm = Node(Normalize(), name="Normalization")
Norm.inputs.template = MNI_template
Norm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

# Normalization of Structural and GM Mask to MNI Space 
Normgm = Node(Normalize(), name="NormalizationGM")
Normgm.inputs.template = MNI_template
Normgm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

# Normalization of Structural and WM Mask to MNI Space 
Normwm = Node(Normalize(), name="NormalizationWM")
Normwm.inputs.template = MNI_template
Normwm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

# Normalization of Structural and CSF Mask to MNI Space 
Normcsf = Node(Normalize(), name="NormalizationCSF")
Normcsf.inputs.template = MNI_template
Normcsf.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

# Normalization of Structural and Brain Mask to MNI Space 
Normmask = Node(Normalize(), name="NormalizationMask")
Normmask.inputs.template = MNI_template
Normmask.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

# Functional Data Smooting 
Smth = Node(Smooth(), name='Smoothing')
Smth.inputs.fwhm = [6, 6, 6]
Smth.inputs.implicit_masking = False 

# WM and CSF Noise Components 
WMnoise = Node(CompCor(), name='WM_Noise_Regressors')
CSFnoise = Node(CompCor(), name='CSF_Noise_Regressors')
WMnoise.inputs.repetition_time = TR
CSFnoise.inputs.repetition_time = TR
WMnoise.inputs.num_components = 5
CSFnoise.inputs.num_components = 5
WMnoise.inputs.pre_filter = 'cosine'
CSFnoise.inputs.pre_filter = 'cosine'

# Motion and Outlier Regressors
Mot = Node(Function(input_names=['motion_params', 'outliers', 'N_motion_reg'], 
                   output_names=['output'], function=Motion_reg_creator), name='Motion_Reg_Creator')

# Create Design Matrix 
DesMat = Node(Function(input_names=['motion_reg', 'wmnoise_reg', 'csfnoise_reg', 'drift'],
                      output_names=['file_dir'], function=Design_Matrix), name='Design_Matrix_Gen')

# Perform GLM 
glm = Node(GLM(), name='GLM')
glm.inputs.out_res_name = 'glm_res.nii'
glm.inputs.output_type = 'NIFTI'
glm.inputs.demean = True 
glm.inputs.des_norm = True 


# Filtering 
bpf = Node(Function(input_names=['signal', 'lowpass_freq', 'highpass_freq', 'TR'], 
                   output_names=['img_out'], function=bandpass_filter), name='BPF')
bpf.inputs.lowpass_freq = 0.09
bpf.inputs.highpass_freq = 0.008
bpf.inputs.TR = TR


# ROI Time Extraction 
roiT = Node(Function(input_names=['atlas', 'img', 'sub_id', 'out_dir'], 
                   output_names=['file_dir'], function=roi_t_extract), name='ROI_Time_Extraction')
roiT.inputs.out_dir = out_dir
roiT.inputs.atlas = atlas

# Quality Check
qc = Node(Function(input_names=['smth_sig', 'den_sig', 'gm_mask', 'out_dir', 'sub_id','N_vox'],
                  output_names=['conn', 'connf'], function=QC), name='QualityCheck')
qc.inputs.out_dir = out_dir

# Save outputs  
datasink = Node(interface=nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.abspath(out_dir)

# %% [markdown]
# ## Pipeline Main Workflow

# %%
preproc = Workflow(name='pipeline')

preproc.connect([
    (infosource   , datasource,    [('subject_id', 'subject_id')]),
    
    (datasource   , Bet,           [('struct', 'in_file')]),
    (Bet          , Seg,           [('out_file', 'data')]),
    (Bet          , Seg,           [('mask_file', 'mask_image')]),
    (Seg          , Norm,          [('bias_corrected_image','source')]),
    (Seg          , Normgm,        [('bias_corrected_image','source')]),
    (Seg          , Normwm,        [('bias_corrected_image','source')]),
    (Seg          , Normcsf,       [('bias_corrected_image','source')]),
    (Seg          , Normmask,      [('bias_corrected_image','source')]),
    (Seg          , gmth,          [('native_gm_image', 'in_file')]),
    (Seg          , wmth,          [('native_wm_image', 'in_file')]),
    (Seg          , csfth,         [('native_csf_image', 'in_file')]),
    (wmth         , erwm,          [('out_file', 'in_file')]),
    (csfth        , ercsf,         [('out_file', 'in_file')]),
    (gmth         , Normgm,        [('out_file', 'apply_to_files')]),
    (erwm         , Normwm,        [('out_file', 'apply_to_files')]),
    (ercsf        , Normcsf,       [('out_file', 'apply_to_files')]),
    (Bet          , Normmask,      [('mask_file', 'apply_to_files')]),
    
    (datasource   , VolRv,         [('func', 'in_file')]),
    (VolRv        , SliceTimeCorr, [('roi_file', 'in_files')]),
    (SliceTimeCorr, ReAlign,       [('timecorrected_files', 'in_files')]),
    (ReAlign      , Art,           [('realigned_files', 'realigned_files'),
                                    ('realignment_parameters', 'realignment_parameters')]),
    (ReAlign      , CoReg,         [('mean_image', 'source'), 
                                    ('realigned_files', 'apply_to_files')]),
    (Seg          , CoReg,         [('bias_corrected_image', 'target')]),
    (CoReg        , Norm,          [('coregistered_files', 'apply_to_files')]),
    
    (Normwm       , WMnoise,       [('normalized_files', 'mask_files')]),
    (Normcsf      , CSFnoise,      [('normalized_files', 'mask_files')]),
    (Norm         , WMnoise,       [('normalized_files', 'realigned_file')]),
    (Norm         , CSFnoise,      [('normalized_files', 'realigned_file')]),
    
    (ReAlign      , Mot,           [('realignment_parameters', 'motion_params')]), 
    (Art          , Mot,           [('outlier_files', 'outliers')]),
    
    (Mot          , DesMat,        [('output', 'motion_reg')]),
    (WMnoise      , DesMat,        [('components_file', 'wmnoise_reg')]),
    (CSFnoise     , DesMat,        [('components_file', 'csfnoise_reg')]),

    (Norm         , Smth,          [('normalized_files', 'in_files')]),
    
    (DesMat       , glm,           [('file_dir', 'design')]),
    (Smth         , glm,           [('smoothed_files', 'in_file')]),
    (Normmask     , glm,           [('normalized_files', 'mask')]),
    
    (glm          , bpf,           [('out_res', 'signal')]),
    
    (bpf          , roiT,          [('img_out', 'img')]),
    (infosource   , roiT,          [('subject_id', 'sub_id')]),
    
    (bpf          , qc,            [('img_out', 'den_sig')]),
    (Smth         , qc,            [('smoothed_files', 'smth_sig')]),
    (Normgm       , qc,            [('normalized_files', 'gm_mask')]),
    (infosource   , qc,            [('subject_id', 'sub_id')]),
    ##################################################################################################
    (infosource   , datasink,      [('subject_id', 'container')]),
    (ReAlign      , datasink,      [('mean_image', 'ReAlign.@mean'),
                                    ('realignment_parameters', 'ReAlign.@param'),
                                    ('realigned_files', 'ReAlign.@RA_files')]),
    (CoReg        , datasink,      [('coregistered_files', 'CoReg.@coreg')]), 
    (Bet          , datasink,      [('out_file','BET.@brain'), 
                                    ('mask_file', 'BET.@brain_mask')]),
    (Seg          , datasink,      [('native_gm_image', 'Segment.@GM'),
                                    ('native_wm_image', 'Segment.@WM'),
                                    ('native_csf_image', 'Segment.@CSF'), 
                                    ('bias_corrected_image', 'Segment.@Bias_Corrected')]),
    (Norm         , datasink,      [('normalized_source', 'Normalization.@StrctNorm'),
                                    ('normalization_parameters', 'Normalization.@Norm_Param'), 
                                    ('normalized_files', 'Normalization.@FcNorm')]),
    (Normgm       , datasink,      [('normalized_files', 'Normalization.@GMMask')]),

    (Normwm       , datasink,      [('normalized_files', 'Normalization.@WMMask')]),
    (Normcsf      , datasink,      [('normalized_files', 'Normalization.@CSFMask')]),
    (Smth         , datasink,      [('smoothed_files', 'Smoothing.@Smoothed')]), 
    (Art          , datasink,      [('outlier_files', 'ART.@Outliers'), 
                                    ('plot_files', 'ART.@Outliers_img'), 
                                    ('displacement_files', 'ART.@Displacement')]),
    (DesMat       , datasink,      [('file_dir', 'DesignMatrix.@DesMat')]),
    (glm          , datasink,      [('out_res', 'GLM_Results.@residuals')]),
    (glm          , datasink,      [('out_file', 'GLM_Results.@betas')]),
    (bpf          , datasink,      [('img_out', 'BandPassFiltered.@final')])
    
])
# Visualize the detailed graph
preproc.write_graph(graph2use='orig', format='png', simple_form=True, 
                    dotfilename='../../Results/preproc_pipeline/Preproc_Pipeline.dot')
preproc.write_graph(graph2use='colored', format='png', simple_form=True, 
                    dotfilename='../../Results/preproc_pipeline/Preproc_Pipeline_col.dot')
# Out:
# 200716-12:42:23,188 nipype.workflow INFO:
# 	 Generated workflow graph: /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Results/preproc_pipeline/Preproc_Pipeline.png (graph2use=orig, simple_form=True).
# 200716-12:42:23,439 nipype.workflow INFO:
# 	 Generated workflow graph: ../../Results/preproc_pipeline/Preproc_Pipeline_col.png (graph2use=colored, simple_form=True).
# '../../Results/preproc_pipeline/Preproc_Pipeline_col.png'

# %% [markdown]
# ## Running Pipeline

# %%
res = preproc.run('MultiProc', plugin_args={'n_procs': 8})
# Out:
# 200716-12:58:13,105 nipype.workflow INFO:
# 	 Workflow pipeline settings: ['check', 'execution', 'logging', 'monitoring']
# 200716-12:58:13,135 nipype.workflow INFO:
# 	 Running in parallel.
# 200716-12:58:13,138 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-12:58:13,248 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.datasource" in "/tmp/tmpes2wul0g/pipeline/_subject_id_s2/datasource".
# 200716-12:58:13,253 nipype.workflow INFO:
# 	 [Node] Running "datasource" ("nipype.interfaces.io.DataGrabber")
# 200716-12:58:13,259 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.datasource".
# 200716-12:58:15,144 nipype.workflow INFO:
# 	 [Job 0] Completed (pipeline.datasource).
# 200716-12:58:15,148 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-12:58:15,225 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.VolumeRemoval" in "/tmp/tmp00l5_y09/pipeline/_subject_id_s2/VolumeRemoval".
# 200716-12:58:15,226 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.BrainExtraction" in "/tmp/tmpmltw30h3/pipeline/_subject_id_s2/BrainExtraction".
# 200716-12:58:15,233 nipype.workflow INFO:
# 	 [Node] Running "VolumeRemoval" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /home/sepehr/Desktop/T1_pipeline/s2/func.nii /tmp/tmp00l5_y09/pipeline/_subject_id_s2/VolumeRemoval/func_roi.nii 3 -1
# 200716-12:58:15,234 nipype.workflow INFO:
# 	 [Node] Running "BrainExtraction" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /home/sepehr/Desktop/T1_pipeline/s2/struct.nii /tmp/tmpmltw30h3/pipeline/_subject_id_s2/BrainExtraction/struct_brain.nii -f 0.30 -m
# 200716-12:58:17,0 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.VolumeRemoval".
# 200716-12:58:17,141 nipype.workflow INFO:
# 	 [Job 1] Completed (pipeline.VolumeRemoval).
# 200716-12:58:17,143 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.BrainExtraction
# 200716-12:58:17,199 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.SliceTimeCorrection" in "/tmp/tmpyc4ktsfo/pipeline/_subject_id_s2/SliceTimeCorrection".
# 200716-12:58:17,207 nipype.workflow INFO:
# 	 [Node] Running "SliceTimeCorrection" ("nipype.interfaces.spm.preprocess.SliceTiming")
# 200716-12:58:18,222 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.BrainExtraction".
# 200716-12:58:19,143 nipype.workflow INFO:
# 	 [Job 6] Completed (pipeline.BrainExtraction).
# 200716-12:58:19,145 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.SliceTimeCorrection
# 200716-12:58:19,199 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Segmentation" in "/tmp/tmpwgt2euzz/pipeline/_subject_id_s2/Segmentation".
# 200716-12:58:19,221 nipype.workflow INFO:
# 	 [Node] Running "Segmentation" ("nipype.interfaces.spm.preprocess.Segment")
# 200716-12:58:21,147 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * pipeline.Segmentation
#                        * pipeline.SliceTimeCorrection
# 200716-12:58:41,551 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.SliceTimeCorrection".
# 200716-12:58:43,166 nipype.workflow INFO:
# 	 [Job 2] Completed (pipeline.SliceTimeCorrection).
# 200716-12:58:43,167 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Segmentation
# 200716-12:58:43,229 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Realignment" in "/tmp/tmp6f3eiwfq/pipeline/_subject_id_s2/Realignment".
# 200716-12:58:43,326 nipype.workflow INFO:
# 	 [Node] Running "Realignment" ("nipype.interfaces.spm.preprocess.Realign")
# 200716-12:58:45,168 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * pipeline.Realignment
#                        * pipeline.Segmentation
# 200716-12:59:25,131 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Segmentation".
# 200716-12:59:25,207 nipype.workflow INFO:
# 	 [Job 7] Completed (pipeline.Segmentation).
# 200716-12:59:25,209 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 4 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Realignment
# 200716-12:59:25,258 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.GMBinaryMask" in "/tmp/tmpb_2dwtx3/pipeline/_subject_id_s2/GMBinaryMask".
# 200716-12:59:25,259 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.NormalizationMask" in "/tmp/tmps0e62ehj/pipeline/_subject_id_s2/NormalizationMask".
# 200716-12:59:25,265 nipype.workflow INFO:
# 	 [Node] Running "GMBinaryMask" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /tmp/tmpwgt2euzz/pipeline/_subject_id_s2/Segmentation/c1struct_brain.nii -thr 0.5000000000 -bin /tmp/tmpb_2dwtx3/pipeline/_subject_id_s2/GMBinaryMask/c1struct_brain_thresh.nii
# 200716-12:59:25,308 nipype.workflow INFO:
# 	 [Node] Running "NormalizationMask" ("nipype.interfaces.spm.preprocess.Normalize")
# 200716-12:59:25,258 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.CSFBinaryMask" in "/tmp/tmp77peuvzi/pipeline/_subject_id_s2/CSFBinaryMask".
# 200716-12:59:25,258 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.WMBinaryMask" in "/tmp/tmpsl0e7hv9/pipeline/_subject_id_s2/WMBinaryMask".
# 200716-12:59:25,320 nipype.workflow INFO:
# 	 [Node] Running "CSFBinaryMask" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /tmp/tmpwgt2euzz/pipeline/_subject_id_s2/Segmentation/c3struct_brain.nii -thr 0.5000000000 -bin /tmp/tmp77peuvzi/pipeline/_subject_id_s2/CSFBinaryMask/c3struct_brain_thresh.nii
# 200716-12:59:25,320 nipype.workflow INFO:
# 	 [Node] Running "WMBinaryMask" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /tmp/tmpwgt2euzz/pipeline/_subject_id_s2/Segmentation/c2struct_brain.nii -thr 0.5000000000 -bin /tmp/tmpsl0e7hv9/pipeline/_subject_id_s2/WMBinaryMask/c2struct_brain_thresh.nii
# 200716-12:59:25,815 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.CSFBinaryMask".
# 200716-12:59:25,878 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.GMBinaryMask".
# 200716-12:59:25,887 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.WMBinaryMask".
# 200716-12:59:27,209 nipype.workflow INFO:
# 	 [Job 11] Completed (pipeline.CSFBinaryMask).
# 200716-12:59:27,210 nipype.workflow INFO:
# 	 [Job 15] Completed (pipeline.WMBinaryMask).
# 200716-12:59:27,212 nipype.workflow INFO:
# 	 [Job 20] Completed (pipeline.GMBinaryMask).
# 200716-12:59:27,213 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 3 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * pipeline.NormalizationMask
#                        * pipeline.Realignment
# 200716-12:59:27,260 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.ErosionCSF" in "/tmp/tmpo75jjjp2/pipeline/_subject_id_s2/ErosionCSF".
# 200716-12:59:27,261 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.ErosionWM" in "/tmp/tmpi6_yzu98/pipeline/_subject_id_s2/ErosionWM".
# 200716-12:59:27,262 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.NormalizationGM" in "/tmp/tmpac08n1xl/pipeline/_subject_id_s2/NormalizationGM".
# 200716-12:59:27,265 nipype.workflow INFO:
# 	 [Node] Running "ErosionCSF" ("nipype.interfaces.fsl.maths.ErodeImage"), a CommandLine Interface with command:
# fslmaths /tmp/tmp77peuvzi/pipeline/_subject_id_s2/CSFBinaryMask/c3struct_brain_thresh.nii -kernel 3D -ero /tmp/tmpo75jjjp2/pipeline/_subject_id_s2/ErosionCSF/c3struct_brain_thresh_ero.nii
# 200716-12:59:27,267 nipype.workflow INFO:
# 	 [Node] Running "ErosionWM" ("nipype.interfaces.fsl.maths.ErodeImage"), a CommandLine Interface with command:
# fslmaths /tmp/tmpsl0e7hv9/pipeline/_subject_id_s2/WMBinaryMask/c2struct_brain_thresh.nii -kernel 3D -ero /tmp/tmpi6_yzu98/pipeline/_subject_id_s2/ErosionWM/c2struct_brain_thresh_ero.nii
# 200716-12:59:27,340 nipype.workflow INFO:
# 	 [Node] Running "NormalizationGM" ("nipype.interfaces.spm.preprocess.Normalize")
# 200716-12:59:29,212 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 12.98/13.98, Free processors: 3/8.
#                      Currently running:
#                        * pipeline.NormalizationGM
#                        * pipeline.ErosionWM
#                        * pipeline.ErosionCSF
#                        * pipeline.NormalizationMask
#                        * pipeline.Realignment
# 200716-12:59:32,380 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Realignment".
# 200716-12:59:33,215 nipype.workflow INFO:
# 	 [Job 3] Completed (pipeline.Realignment).
# 200716-12:59:33,218 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 13.18/13.98, Free processors: 4/8.
#                      Currently running:
#                        * pipeline.NormalizationGM
#                        * pipeline.ErosionWM
#                        * pipeline.ErosionCSF
#                        * pipeline.NormalizationMask
# 200716-12:59:33,290 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Coregistration" in "/tmp/tmp008d7r_u/pipeline/_subject_id_s2/Coregistration".
# 200716-12:59:33,289 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.ArtifactDetection" in "/tmp/tmpkzgs8r_d/pipeline/_subject_id_s2/ArtifactDetection".
# 200716-12:59:33,306 nipype.workflow INFO:
# 	 [Node] Running "ArtifactDetection" ("nipype.algorithms.rapidart.ArtifactDetect")
# 200716-12:59:33,385 nipype.workflow INFO:
# 	 [Node] Running "Coregistration" ("nipype.interfaces.spm.preprocess.Coregister")
# 200716-12:59:33,806 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.ArtifactDetection".
# 200716-12:59:35,218 nipype.workflow INFO:
# 	 [Job 4] Completed (pipeline.ArtifactDetection).
# 200716-12:59:35,220 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 1 jobs ready. Free memory (GB): 12.98/13.98, Free processors: 3/8.
#                      Currently running:
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
#                        * pipeline.ErosionWM
#                        * pipeline.ErosionCSF
#                        * pipeline.NormalizationMask
# 200716-12:59:35,277 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Motion_Reg_Creator" in "/tmp/tmpg60kq264/pipeline/_subject_id_s2/Motion_Reg_Creator".
# 200716-12:59:35,283 nipype.workflow INFO:
# 	 [Node] Running "Motion_Reg_Creator" ("nipype.interfaces.utility.wrappers.Function")
# <string>:18: UserWarning: loadtxt: Empty input file: "/tmp/tmpkzgs8r_d/pipeline/_subject_id_s2/ArtifactDetection/art.rafunc_roi_outliers.txt"
# 200716-12:59:35,308 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Motion_Reg_Creator".
# 200716-12:59:37,219 nipype.workflow INFO:
# 	 [Job 5] Completed (pipeline.Motion_Reg_Creator).
# 200716-12:59:37,225 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 12.98/13.98, Free processors: 3/8.
#                      Currently running:
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
#                        * pipeline.ErosionWM
#                        * pipeline.ErosionCSF
#                        * pipeline.NormalizationMask
# 200716-12:59:39,80 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.ErosionCSF".
# 200716-12:59:39,221 nipype.workflow INFO:
# 	 [Job 12] Completed (pipeline.ErosionCSF).
# 200716-12:59:39,224 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 13.18/13.98, Free processors: 4/8.
#                      Currently running:
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
#                        * pipeline.ErosionWM
#                        * pipeline.NormalizationMask
# 200716-12:59:39,289 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.NormalizationCSF" in "/tmp/tmp7yxsdul0/pipeline/_subject_id_s2/NormalizationCSF".
# 200716-12:59:39,369 nipype.workflow INFO:
# 	 [Node] Running "NormalizationCSF" ("nipype.interfaces.spm.preprocess.Normalize")
# 200716-12:59:39,812 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.ErosionWM".
# 200716-12:59:41,224 nipype.workflow INFO:
# 	 [Job 16] Completed (pipeline.ErosionWM).
# 200716-12:59:41,227 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 13.18/13.98, Free processors: 4/8.
#                      Currently running:
#                        * pipeline.NormalizationCSF
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
#                        * pipeline.NormalizationMask
# 200716-12:59:41,297 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.NormalizationWM" in "/tmp/tmpmxuyowud/pipeline/_subject_id_s2/NormalizationWM".
# 200716-12:59:41,390 nipype.workflow INFO:
# 	 [Node] Running "NormalizationWM" ("nipype.interfaces.spm.preprocess.Normalize")
# 200716-12:59:43,226 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 12.98/13.98, Free processors: 3/8.
#                      Currently running:
#                        * pipeline.NormalizationWM
#                        * pipeline.NormalizationCSF
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
#                        * pipeline.NormalizationMask
# 200716-12:59:51,75 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.NormalizationMask".
# 200716-12:59:51,234 nipype.workflow INFO:
# 	 [Job 22] Completed (pipeline.NormalizationMask).
# 200716-12:59:51,236 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 13.18/13.98, Free processors: 4/8.
#                      Currently running:
#                        * pipeline.NormalizationWM
#                        * pipeline.NormalizationCSF
#                        * pipeline.Coregistration
#                        * pipeline.NormalizationGM
# 200716-12:59:53,196 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.NormalizationGM".
# 200716-12:59:53,234 nipype.workflow INFO:
# 	 [Job 21] Completed (pipeline.NormalizationGM).
# 200716-12:59:53,236 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * pipeline.NormalizationWM
#                        * pipeline.NormalizationCSF
#                        * pipeline.Coregistration
# 200716-13:00:04,556 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.NormalizationCSF".
# 200716-13:00:05,245 nipype.workflow INFO:
# 	 [Job 13] Completed (pipeline.NormalizationCSF).
# 200716-13:00:05,247 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * pipeline.NormalizationWM
#                        * pipeline.Coregistration
# 200716-13:00:05,954 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.NormalizationWM".
# 200716-13:00:07,247 nipype.workflow INFO:
# 	 [Job 17] Completed (pipeline.NormalizationWM).
# 200716-13:00:07,249 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Coregistration
# 200716-13:05:07,638 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Coregistration".
# 200716-13:05:09,525 nipype.workflow INFO:
# 	 [Job 8] Completed (pipeline.Coregistration).
# 200716-13:05:09,532 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-13:05:09,578 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Normalization" in "/tmp/tmp9oedjrt8/pipeline/_subject_id_s2/Normalization".
# 200716-13:05:11,529 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Normalization
# 200716-13:07:53,705 nipype.workflow INFO:
# 	 [Node] Running "Normalization" ("nipype.interfaces.spm.preprocess.Normalize")
# 200716-13:10:40,626 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Normalization".
# 200716-13:10:41,864 nipype.workflow INFO:
# 	 [Job 9] Completed (pipeline.Normalization).
# 200716-13:10:41,873 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-13:10:41,976 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Smoothing" in "/tmp/tmpbpv8bwmr/pipeline/_subject_id_s2/Smoothing".
# 200716-13:10:41,986 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.CSF_Noise_Regressors" in "/tmp/tmp3170syw3/pipeline/_subject_id_s2/CSF_Noise_Regressors".
# 200716-13:10:41,992 nipype.workflow INFO:
# 	 [Node] Running "Smoothing" ("nipype.interfaces.spm.preprocess.Smooth")
# 200716-13:10:41,997 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.WM_Noise_Regressors" in "/tmp/tmpaia_b3co/pipeline/_subject_id_s2/WM_Noise_Regressors".
# 200716-13:10:42,11 nipype.workflow INFO:
# 	 [Node] Running "CSF_Noise_Regressors" ("nipype.algorithms.confounds.CompCor")
# 200716-13:10:42,19 nipype.workflow INFO:
# 	 [Node] Running "WM_Noise_Regressors" ("nipype.algorithms.confounds.CompCor")
# 200716-13:10:43,867 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * pipeline.WM_Noise_Regressors
#                        * pipeline.CSF_Noise_Regressors
#                        * pipeline.Smoothing
# /home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/algorithms/confounds.py:1099: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   betas = np.linalg.lstsq(X, data.T)[0]
# /home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/algorithms/confounds.py:1099: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   betas = np.linalg.lstsq(X, data.T)[0]
# 200716-13:10:46,351 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.CSF_Noise_Regressors".
# 200716-13:10:47,149 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.WM_Noise_Regressors".
# 200716-13:10:47,868 nipype.workflow INFO:
# 	 [Job 14] Completed (pipeline.CSF_Noise_Regressors).
# 200716-13:10:47,869 nipype.workflow INFO:
# 	 [Job 18] Completed (pipeline.WM_Noise_Regressors).
# 200716-13:10:47,871 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Smoothing
# 200716-13:10:47,933 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.Design_Matrix_Gen" in "/tmp/tmpl56p4nhx/pipeline/_subject_id_s2/Design_Matrix_Gen".
# 200716-13:10:47,961 nipype.workflow INFO:
# 	 [Node] Running "Design_Matrix_Gen" ("nipype.interfaces.utility.wrappers.Function")
# 200716-13:10:48,118 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Design_Matrix_Gen".
# 200716-13:10:49,870 nipype.workflow INFO:
# 	 [Job 19] Completed (pipeline.Design_Matrix_Gen).
# 200716-13:10:49,873 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.Smoothing
# 200716-13:11:34,300 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.Smoothing".
# 200716-13:11:35,917 nipype.workflow INFO:
# 	 [Job 10] Completed (pipeline.Smoothing).
# 200716-13:11:35,923 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-13:11:36,917 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.GLM" in "/tmp/tmp6g2mdbv9/pipeline/_subject_id_s2/GLM".
# 200716-13:11:37,920 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.GLM
# 200716-13:11:38,450 nipype.workflow INFO:
# 	 [Node] Running "GLM" ("nipype.interfaces.fsl.model.GLM"), a CommandLine Interface with command:
# fsl_glm -i /tmp/tmpbpv8bwmr/pipeline/_subject_id_s2/Smoothing/swrrafunc_roi.nii -d /tmp/tmpdoajlt/DesMat.txt -o swrrafunc_roi_glm.nii --demean --des_norm -m /tmp/tmps0e62ehj/pipeline/_subject_id_s2/NormalizationMask/wstruct_brain_mask.nii --out_res=glm_res.nii
# 200716-13:11:51,354 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.GLM".
# 200716-13:11:51,932 nipype.workflow INFO:
# 	 [Job 23] Completed (pipeline.GLM).
# 200716-13:11:51,939 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-13:11:52,597 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.BPF" in "/tmp/tmpgthemmvd/pipeline/_subject_id_s2/BPF".
# 200716-13:11:52,607 nipype.workflow INFO:
# 	 [Node] Running "BPF" ("nipype.interfaces.utility.wrappers.Function")
# 200716-13:11:53,936 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.BPF
# 200716-13:12:07,502 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.BPF".
# 200716-13:12:07,948 nipype.workflow INFO:
# 	 [Job 24] Completed (pipeline.BPF).
# 200716-13:12:07,955 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200716-13:12:08,239 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.datasink" in "/tmp/tmputlpjmq5/pipeline/_subject_id_s2/datasink".
# 200716-13:12:08,334 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.QualityCheck" in "/tmp/tmp8h5l0e54/pipeline/_subject_id_s2/QualityCheck".
# 200716-13:12:08,348 nipype.workflow INFO:
# 	 [Node] Setting-up "pipeline.ROI_Time_Extraction" in "/tmp/tmp1ua7vch7/pipeline/_subject_id_s2/ROI_Time_Extraction".
# 200716-13:12:08,353 nipype.workflow INFO:
# 	 [Node] Running "QualityCheck" ("nipype.interfaces.utility.wrappers.Function")
# 200716-13:12:08,359 nipype.workflow INFO:
# 	 [Node] Running "ROI_Time_Extraction" ("nipype.interfaces.utility.wrappers.Function")
# 200716-13:12:08,740 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200716-13:12:09,699 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.ROI_Time_Extraction".
# 200716-13:12:09,950 nipype.workflow INFO:
# 	 [Job 27] Completed (pipeline.ROI_Time_Extraction).
# 200716-13:12:09,956 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * pipeline.QualityCheck
#                        * pipeline.datasink
# /home/sepehr/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2534: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/sepehr/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2535: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /home/sepehr/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/sepehr/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# 200716-13:12:41,181 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.QualityCheck".
# 200716-13:12:41,983 nipype.workflow INFO:
# 	 [Job 26] Completed (pipeline.QualityCheck).
# 200716-13:12:41,990 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * pipeline.datasink
# 200716-13:16:00,124 nipype.workflow INFO:
# 	 [Node] Finished "pipeline.datasink".
# 200716-13:16:00,187 nipype.workflow INFO:
# 	 [Job 25] Completed (pipeline.datasink).
# 200716-13:16:00,189 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
