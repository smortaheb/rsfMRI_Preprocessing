# %%
# Import necessary packages
import os 
import random 
import string 
import nipype.interfaces.io as nio 
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util 
import matplotlib.pylab as plt 
import nibabel as nb
import numpy as np 

from os.path import abspath 
from nipype import Workflow, Node, Function 
from nipype.interfaces.fsl import ExtractROI, BET, GLM, ErodeImage, ApplyMask, FAST 
from nipype.interfaces.spm import SliceTiming, Realign, Coregister, Normalize, Smooth, ApplyTransform
from nipype.interfaces.spm.utils import Reslice
from nipype.interfaces.afni import Bandpass
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.base import Undefined
from nipype.utils.filemanip import filename_to_list
from nilearn.plotting import plot_anat
from nipype.interfaces import IdentityInterface
from nipype.algorithms.confounds import CompCor, ACompCor
from nilearn.signal import clean 
from nipype.interfaces.io import SelectFiles, DataSink
from functions import Design_Matrix, Motion_reg_creator, QC, roi_t_extract, tmp_file_removal

# %% [markdown]
# ## Initialization

# %%
# Initialize paths and parameters here 

# Main directory of the data 
data_dir = "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data"

# Main directory to save results 
out_dir = "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Preproc_MNI"

# SPM and FSL main directories
SPM_dir = '/home/sepehr/My_Documents/Softwares/SPM/spm12'
FSL_dir = '/usr/local/fsl'

# fMRI acquisition parameters
Num_of_Slices = 34 
TR = 2.04
TA = TR - TR/float(Num_of_Slices)

# Some Parameters and files
#you should give full permission to the fsl folder (sudo chmod -R a+rwx /path/to/fsl)

num_of_scans_rmv = 200 # Number of initial scans to remove
MNI_template_comp = FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii.gz'
sig = nb.load(MNI_template_comp)
nb.save(sig, FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii')
MNI_template = FSL_dir + '/data/standard/MNI152_T1_2mm_brain.nii'
atlas = '/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Atlas_files/Schaefer_100par_7net_2mm/atlas.nii'

# List of subjects to apply pipeline on  
subject_list = ['s8178']

# %% [markdown]
# ## Node Definition

# %%
# Structural Workflow Nodes 

# Brain Extraction 
Bet = Node(BET(), name='BrainExtraction')
Bet.inputs.mask = True 
Bet.inputs.frac = 0.3 
Bet.inputs.output_type = 'NIFTI'

# Segmentation and Bias Correction 
Seg = Node(FAST(), name='Segmentation')
Seg.inputs.number_classes = 3 
Seg.inputs.output_biascorrected = True 
Seg.inputs.img_type = 1 #T1 >> 2 for T2 and 3 for PD
Seg.inputs.segments = True 
Seg.inputs.no_pve = True 
Seg.inputs.probability_maps = False 
Seg.inputs.output_type = 'NIFTI'
pickindex = lambda x, i: x[i]

# Erosion of WM Mask 
erwm = Node(ErodeImage(), name='ErosionWM')
erwm.inputs.kernel_shape = '3D'
erwm.inputs.output_type = 'NIFTI'

# Erosion of CSF Mask 
ercsf = Node(ErodeImage(), name='ErosionCSF')
ercsf.inputs.kernel_shape = '3D'
ercsf.inputs.output_type = 'NIFTI'

# Normalization of GM Mask to MNI Space 
Normgm = Node(Normalize(), name="NormGM")
Normgm.inputs.template = MNI_template
Normgm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]
Normgm.inputs.write_interp = 0

# Normalization of WM Mask to MNI Space 
Normwm = Node(Normalize(), name="NormWM")
Normwm.inputs.template = MNI_template
Normwm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]
Normwm.inputs.write_interp = 0

# Normalization of CSF Mask to MNI Space 
Normcsf = Node(Normalize(), name="NormCSF")
Normcsf.inputs.template = MNI_template
Normcsf.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]
Normcsf.inputs.write_interp = 0

# Normalization of Brain Mask to MNI Space 
Normmask = Node(Normalize(), name="NormMask")
Normmask.inputs.template = MNI_template
Normmask.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]
Normmask.inputs.write_interp = 0

##############################################################################################

# Functional Workflow Nodes 

# Initial Volume Removal 
VolRv = Node(ExtractROI(), name="VolumeRemoval")
VolRv.inputs.t_min = num_of_scans_rmv
VolRv.inputs.t_size = -1
VolRv.inputs.output_type = 'NIFTI'

# Realignment of functional data 
ReAlign = Node(Realign(), name="Realignment")
ReAlign.inputs.quality = 0.9
ReAlign.inputs.fwhm = 5
ReAlign.inputs.separation = 4 
ReAlign.inputs.register_to_mean = True 
ReAlign.inputs.interp = 2
ReAlign.inputs.write_interp = 2
ReAlign.inputs.write_mask = True 

# ART Artifact Detection 
Art = Node(ArtifactDetect(), name="ArtifactDetection")
Art.inputs.parameter_source = 'SPM'
Art.inputs.use_norm = Undefined
Art.inputs.rotation_threshold = 0.05
Art.inputs.translation_threshold = 3 
Art.inputs.zintensity_threshold = 3
Art.inputs.mask_type = 'spm_global'
Art.inputs.save_plot = True 

# Coregistration of functional data to structural data in native space 
CoReg = Node(Coregister(), name='Coregistration')
CoReg.inputs.jobtype = 'estimate'
CoReg.inputs.cost_function = 'nmi'
CoReg.inputs.separation = [4, 2]
CoReg.inputs.tolerance = [0.02, 0.02, 0.02, 
                          0.001, 0.001, 0.001, 
                          0.01, 0.01, 0.01, 
                          0.001, 0.001, 0.001]

# Normalization of Functional Images to MNI Space 
Norm = Node(Normalize(), name="Normalization")
Norm.inputs.template = MNI_template
Norm.inputs.write_bounding_box = [[-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]]

################################################################################################################

# Denoising Workflow Nodes

# Motion and Outlier Regressors Creation 
Mot = Node(Function(input_names=['motion_params', 'outliers', 'N_motion_reg'], 
                   output_names=['output'], function=Motion_reg_creator), name='MotionReg')

# WM and CSF Noise Components Extraction
WMnoise = Node(CompCor(), name='WMReg')
CSFnoise = Node(CompCor(), name='CSFReg')
WMnoise.inputs.repetition_time = TR
CSFnoise.inputs.repetition_time = TR
WMnoise.inputs.num_components = 5
CSFnoise.inputs.num_components = 5
WMnoise.inputs.pre_filter = 'cosine'
CSFnoise.inputs.pre_filter = 'cosine'

# Create Design Matrix 
DesMat = Node(Function(input_names=['motion_reg', 'wmnoise_reg', 'csfnoise_reg'],
                      output_names=['file_dir'], function=Design_Matrix), name='DesignMat')

# Smooting 
Smth = Node(Smooth(), name='Smoothing')
Smth.inputs.fwhm = [8, 8, 8]
Smth.inputs.implicit_masking = False 

# Perform GLM 
glm = Node(GLM(), name='GLM')
glm.inputs.out_res_name = 'glm_res.nii'
glm.inputs.output_type = 'NIFTI'
glm.inputs.demean = True 
glm.inputs.des_norm = True 

# Bandpass Filtering
bpf = Node(Bandpass(), name='BPF')
bpf.inputs.lowpass = 0.09
bpf.inputs.highpass = 0.008
bpf.inputs.tr = TR
bpf.inputs.outputtype = 'NIFTI'

###############################################################################################################

# Input and Output Stream Nodes 

# Reading subjects' structural and functional data (data should be stored properly)

infosource = Node(
    interface=util.IdentityInterface(fields=['subject_id']), name="infosource")
infosource.iterables = ('subject_id', subject_list)

# Input Node 
templates = {
    'anat':data_dir+'/{subject_id}/struct.nii',
    'func':data_dir+'/{subject_id}/func.nii'
}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# Output Node
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = out_dir

# ROI Time Extraction 
roiT = Node(Function(input_names=['atlas', 'img', 'sub_id', 'out_dir'], 
                   output_names=['file_dir'], function=roi_t_extract), name='ROI_Time_Extraction')
roiT.inputs.out_dir = out_dir
roiT.inputs.atlas = atlas

# Tmp file removal 
tmpf = Node(Function(input_names=['dsink', 'data_dir', 'subj_id', 'file_dir'], 
                     function=tmp_file_removal), name='Tmp_File_Rmv')
tmpf.inputs.data_dir = data_dir 
tmpf.inputs.nodes = which_nodes
tmpf.base_directory = data_dir + '/tmp'

# %% [markdown]
# ## WorkFlows

# %%
# Structural Workflow 
strct_workflow = Workflow(name='Structural')
strct_workflow.base_dir = data_dir 
strct_workflow.connect(Bet, 'out_file', Seg, 'in_files')
strct_workflow.connect(Seg, ('tissue_class_files', pickindex, 2), erwm, 'in_file')
strct_workflow.connect(Seg, ('tissue_class_files', pickindex, 0), ercsf, 'in_file')
strct_workflow.connect(Seg, 'restored_image', Normgm, 'source')
strct_workflow.connect(Seg, 'restored_image', Normwm, 'source')
strct_workflow.connect(Seg, 'restored_image', Normcsf, 'source')
strct_workflow.connect(Seg, 'restored_image', Normmask, 'source')
strct_workflow.connect(erwm, 'out_file', Normwm, 'apply_to_files')
strct_workflow.connect(ercsf, 'out_file', Normcsf, 'apply_to_files')
strct_workflow.connect(Seg, ('tissue_class_files', pickindex, 1), Normgm, 'apply_to_files')
strct_workflow.connect(Bet, 'mask_file', Normmask, 'apply_to_files')

# Functional Workflow 
func_workflow = Workflow(name='Functional')
func_workflow.base_dir = data_dir 
func_workflow.connect(VolRv, 'roi_file', ReAlign, 'in_files')
func_workflow.connect(ReAlign, 'realigned_files', Art, 'realigned_files')
func_workflow.connect(ReAlign, 'realignment_parameters', Art, 'realignment_parameters')
func_workflow.connect(ReAlign, 'mean_image', CoReg, 'source')
func_workflow.connect(ReAlign, 'realigned_files', CoReg, 'apply_to_files')
func_workflow.connect(CoReg, 'coregistered_files', Norm, 'apply_to_files')

#Denoising Workflow 
den_workflow = Workflow(name='Denoising')
den_workflow.base_dir = data_dir 
den_workflow.connect(Mot, 'output', DesMat, 'motion_reg')
den_workflow.connect(WMnoise, 'components_file', DesMat, 'wmnoise_reg')
den_workflow.connect(CSFnoise, 'components_file', DesMat, 'csfnoise_reg')
den_workflow.connect(DesMat, 'file_dir', glm, 'design')
den_workflow.connect(Smth, 'smoothed_files', glm, 'in_file')
den_workflow.connect(glm, 'out_res', bpf, 'in_file')

# Connect Workflows 
scaffoldflow = Workflow(name='scaffoldflow')
scaffoldflow.base_dir = data_dir 
scaffoldflow.connect([
    (infosource, selectfiles, [('subject_id', 'subject_id')]),
    (selectfiles, strct_workflow, [('anat', 'BrainExtraction.in_file')]),
    (selectfiles, func_workflow, [('func', 'VolumeRemoval.in_file')]),
    (strct_workflow, func_workflow, [('Segmentation.restored_image','Coregistration.target')]),
    (strct_workflow, func_workflow, [('Segmentation.restored_image', 'Normalization.source')]),
    (func_workflow, den_workflow, [('Normalization.normalized_files', 'WMReg.realigned_file')]),
    (func_workflow, den_workflow, [('Normalization.normalized_files', 'CSFReg.realigned_file')]),
    (func_workflow, den_workflow, [('Normalization.normalized_files', 'Smoothing.in_files')]),
    (func_workflow, den_workflow, [('Realignment.realignment_parameters', 'MotionReg.motion_params')]),
    (func_workflow, den_workflow, [('ArtifactDetection.outlier_files', 'MotionReg.outliers')]),
    (strct_workflow, den_workflow, [('NormWM.normalized_files', 'WMReg.mask_files')]),
    (strct_workflow, den_workflow, [('NormCSF.normalized_files', 'CSFReg.mask_files')]),
    (strct_workflow, den_workflow, [('NormMask.normalized_files', 'GLM.mask')]),
    (den_workflow, roiT, [('BPF.out_file', 'img')]),
    (infosource, roiT, [('subject_id', 'sub_id')]),
    #############################################################################
    (infosource, datasink, [('subject_id', 'container')]),
    (func_workflow, datasink, [('VolumeRemoval.roi_file', 'VolumeRemoval.@file')]),
    (func_workflow, datasink, [('Realignment.mean_image', 'Realignment.@mean')]),
    (func_workflow, datasink, [('Realignment.realignment_parameters', 'Realignment.@param')]),
    (func_workflow, datasink, [('Realignment.realigned_files', 'Realignment.@ra_files')]),
    (func_workflow, datasink, [('Coregistration.coregistered_files', 'Coregistration.@coreg')]),
    (func_workflow, datasink, [('Normalization.normalized_source', 'Normalization.@source')]),
    (func_workflow, datasink, [('Normalization.normalization_parameters', 'Normalization.@params')]),
    (func_workflow, datasink, [('Normalization.normalized_files', 'Normalization.@files')]),
    (func_workflow, datasink, [('ArtifactDetection.outlier_files', 'ART.@outliers')]),
    (func_workflow, datasink, [('ArtifactDetection.plot_files', 'ART.@outliers_img')]),
    (func_workflow, datasink, [('ArtifactDetection.displacement_files', 'ART.@displacement')]),
    
    
    (strct_workflow, datasink, [('BrainExtraction.out_file', 'BET.@brain')]),
    (strct_workflow, datasink, [('BrainExtraction.mask_file', 'BET.@mask')]),
    (strct_workflow, datasink, [('Segmentation.tissue_class_files', 'Segmentation.@masks')]),
    (strct_workflow, datasink, [('Segmentation.restored_image', 'Segmentation.@bias_corrected')]),
    (strct_workflow, datasink, [('NormGM.normalized_files', 'Normalization.@gm')]),
    (strct_workflow, datasink, [('NormWM.normalized_files', 'Normalization.@wm')]),
    (strct_workflow, datasink, [('NormCSF.normalized_files', 'Normalization.@csf')]),
    (strct_workflow, datasink, [('NormMask.normalized_files', 'Normalization.@mask')]),

    (den_workflow, datasink, [('Smoothing.smoothed_files', 'Smoothing.@smoothed')]),
    (den_workflow, datasink, [('DesignMat.file_dir', 'DesignMatrix.@desmat')]),
    (den_workflow, datasink, [('GLM.out_res', 'GLM_Results.@res')]),
    (den_workflow, datasink, [('GLM.out_file', 'GLM_Results.@betas')]),
    (den_workflow, datasink, [('BPF.out_file', 'BPF.@final')]),
    
    (datasink     , tmpf,          [('out_file', 'dsink')]),
    (roiT         , tmpf,          [('file_dir', 'file_dir')]),
    (infosource   , tmpf,          [('subject_id', 'subj_id')])
    
])
scaffoldflow.write_graph(graph2use='orig', format='png', simple_form=True, 
                    dotfilename='../../Results/preproc_pipeline/Preproc_Pipeline.dot')
scaffoldflow.write_graph(graph2use='colored', format='png', simple_form=True, 
                    dotfilename='../../Results/preproc_pipeline/Preproc_Pipeline_col.dot')
# Out:
# 200805-09:45:28,969 nipype.workflow INFO:
# 	 Generated workflow graph: /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Results/preproc_pipeline/Preproc_Pipeline.png (graph2use=orig, simple_form=True).
# 200805-09:45:29,226 nipype.workflow INFO:
# 	 Generated workflow graph: ../../Results/preproc_pipeline/Preproc_Pipeline_col.png (graph2use=colored, simple_form=True).
# '../../Results/preproc_pipeline/Preproc_Pipeline_col.png'

# %% [markdown]
# ## Running Pipeline

# %%
res = scaffoldflow.run('MultiProc', plugin_args={'n_procs': 8})
# Out:
# 200805-09:45:33,697 nipype.workflow INFO:
# 	 Workflow scaffoldflow settings: ['check', 'execution', 'logging', 'monitoring']
# 200805-09:45:33,718 nipype.workflow INFO:
# 	 Running in parallel.
# 200805-09:45:33,721 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-09:45:33,821 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.selectfiles" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/_subject_id_s8178/selectfiles".
# 200805-09:45:33,827 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 200805-09:45:33,851 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.selectfiles".
# 200805-09:45:35,727 nipype.workflow INFO:
# 	 [Job 0] Completed (scaffoldflow.selectfiles).
# 200805-09:45:35,730 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-09:45:35,805 nipype.workflow INFO:
# 	 [Job 1] Cached (scaffoldflow.Functional.VolumeRemoval).
# 200805-09:45:35,809 nipype.workflow INFO:
# 	 [Job 5] Cached (scaffoldflow.Structural.BrainExtraction).
# 200805-09:45:37,785 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.Segmentation" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/Segmentation".
# 200805-09:45:37,785 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Functional.Realignment" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Functional/_subject_id_s8178/Realignment".
# 200805-09:45:37,795 nipype.workflow INFO:
# 	 [Node] Running "Segmentation" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -t 1 --nopve -n 3 -B -g -S 1 /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/Segmentation/struct_brain.nii
# 200805-09:45:38,336 nipype.workflow INFO:
# 	 [Node] Running "Realignment" ("nipype.interfaces.spm.preprocess.Realign")
# 200805-09:45:39,727 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Structural.Segmentation
#                        * scaffoldflow.Functional.Realignment
# 200805-09:49:26,467 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Functional.Realignment".
# 200805-09:49:27,922 nipype.workflow INFO:
# 	 [Job 2] Completed (scaffoldflow.Functional.Realignment).
# 200805-09:49:27,924 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Structural.Segmentation
# 200805-09:49:27,970 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Functional.ArtifactDetection" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Functional/_subject_id_s8178/ArtifactDetection".
# 200805-09:49:27,979 nipype.workflow INFO:
# 	 [Node] Running "ArtifactDetection" ("nipype.algorithms.rapidart.ArtifactDetect")
# /home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/algorithms/rapidart.py:443: RuntimeWarning: invalid value encountered in greater
#   (np.nanmean(vol) / self.inputs.global_threshold)
# 200805-09:49:29,925 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Functional.ArtifactDetection
#                        * scaffoldflow.Structural.Segmentation
# 200805-09:49:30,225 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Functional.ArtifactDetection".
# 200805-09:49:31,926 nipype.workflow INFO:
# 	 [Job 3] Completed (scaffoldflow.Functional.ArtifactDetection).
# 200805-09:49:31,928 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Structural.Segmentation
# 200805-09:49:31,973 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.MotionReg" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/MotionReg".
# 200805-09:49:31,994 nipype.workflow INFO:
# 	 [Node] Running "MotionReg" ("nipype.interfaces.utility.wrappers.Function")
# 200805-09:49:32,84 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.MotionReg".
# 200805-09:49:33,926 nipype.workflow INFO:
# 	 [Job 4] Completed (scaffoldflow.Denoising.MotionReg).
# 200805-09:49:33,928 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Structural.Segmentation
# 200805-09:59:39,198 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.Segmentation".
# 200805-09:59:40,444 nipype.workflow INFO:
# 	 [Job 6] Completed (scaffoldflow.Structural.Segmentation).
# 200805-09:59:40,448 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-09:59:40,502 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.ErosionWM" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/ErosionWM".
# 200805-09:59:40,501 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.ErosionCSF" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/ErosionCSF".
# 200805-09:59:40,508 nipype.workflow INFO:
# 	 [Node] Running "ErosionCSF" ("nipype.interfaces.fsl.maths.ErodeImage"), a CommandLine Interface with command:
# fslmaths /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/Segmentation/struct_brain_seg_0.nii -kernel 3D -ero /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/ErosionCSF/struct_brain_seg_0_ero.nii
# 200805-09:59:40,508 nipype.workflow INFO:
# 	 [Node] Running "ErosionWM" ("nipype.interfaces.fsl.maths.ErodeImage"), a CommandLine Interface with command:
# fslmaths /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/Segmentation/struct_brain_seg_2.nii -kernel 3D -ero /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/ErosionWM/struct_brain_seg_2_ero.nii
# 200805-09:59:40,502 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Functional.Coregistration" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Functional/_subject_id_s8178/Coregistration".
# 200805-09:59:40,502 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.NormGM" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/NormGM".
# 200805-09:59:40,502 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.NormMask" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/NormMask".
# 200805-09:59:40,693 nipype.workflow INFO:
# 	 [Node] Running "NormMask" ("nipype.interfaces.spm.preprocess.Normalize")
# 200805-09:59:40,739 nipype.workflow INFO:
# 	 [Node] Running "NormGM" ("nipype.interfaces.spm.preprocess.Normalize")
# 200805-09:59:41,211 nipype.workflow INFO:
# 	 [Node] Running "Coregistration" ("nipype.interfaces.spm.preprocess.Coregister")
# 200805-09:59:42,445 nipype.workflow INFO:
# 	 [MultiProc] Running 5 tasks, and 0 jobs ready. Free memory (GB): 12.98/13.98, Free processors: 3/8.
#                      Currently running:
#                        * scaffoldflow.Structural.ErosionWM
#                        * scaffoldflow.Structural.ErosionCSF
#                        * scaffoldflow.Structural.NormGM
#                        * scaffoldflow.Structural.NormMask
#                        * scaffoldflow.Functional.Coregistration
# 200805-10:00:16,708 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.ErosionCSF".
# 200805-10:00:17,878 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.NormMask".
# 200805-10:00:18,475 nipype.workflow INFO:
# 	 [Job 10] Completed (scaffoldflow.Structural.NormMask).
# 200805-10:00:18,477 nipype.workflow INFO:
# 	 [Job 12] Completed (scaffoldflow.Structural.ErosionCSF).
# 200805-10:00:18,480 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * scaffoldflow.Structural.ErosionWM
#                        * scaffoldflow.Structural.NormGM
#                        * scaffoldflow.Functional.Coregistration
# 200805-10:00:18,538 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.NormCSF" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/NormCSF".
# 200805-10:00:18,704 nipype.workflow INFO:
# 	 [Node] Running "NormCSF" ("nipype.interfaces.spm.preprocess.Normalize")
# 200805-10:00:19,462 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.NormGM".
# 200805-10:00:20,477 nipype.workflow INFO:
# 	 [Job 11] Completed (scaffoldflow.Structural.NormGM).
# 200805-10:00:20,479 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * scaffoldflow.Structural.NormCSF
#                        * scaffoldflow.Structural.ErosionWM
#                        * scaffoldflow.Functional.Coregistration
# 200805-10:00:22,410 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.ErosionWM".
# 200805-10:00:22,480 nipype.workflow INFO:
# 	 [Job 15] Completed (scaffoldflow.Structural.ErosionWM).
# 200805-10:00:22,482 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Structural.NormCSF
#                        * scaffoldflow.Functional.Coregistration
# 200805-10:00:22,547 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Structural.NormWM" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/NormWM".
# 200805-10:00:22,737 nipype.workflow INFO:
# 	 [Node] Running "NormWM" ("nipype.interfaces.spm.preprocess.Normalize")
# 200805-10:00:24,482 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * scaffoldflow.Structural.NormWM
#                        * scaffoldflow.Structural.NormCSF
#                        * scaffoldflow.Functional.Coregistration
# 200805-10:00:28,362 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Functional.Coregistration".
# 200805-10:00:28,485 nipype.workflow INFO:
# 	 [Job 7] Completed (scaffoldflow.Functional.Coregistration).
# 200805-10:00:28,487 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Structural.NormWM
#                        * scaffoldflow.Structural.NormCSF
# 200805-10:00:28,540 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Functional.Normalization" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Functional/_subject_id_s8178/Normalization".
# 200805-10:00:29,87 nipype.workflow INFO:
# 	 [Node] Running "Normalization" ("nipype.interfaces.spm.preprocess.Normalize")
# 200805-10:00:30,488 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * scaffoldflow.Functional.Normalization
#                        * scaffoldflow.Structural.NormWM
#                        * scaffoldflow.Structural.NormCSF
# 200805-10:00:53,648 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.NormCSF".
# 200805-10:00:54,509 nipype.workflow INFO:
# 	 [Job 13] Completed (scaffoldflow.Structural.NormCSF).
# 200805-10:00:54,511 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Functional.Normalization
#                        * scaffoldflow.Structural.NormWM
# 200805-10:00:57,325 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Structural.NormWM".
# 200805-10:00:58,513 nipype.workflow INFO:
# 	 [Job 16] Completed (scaffoldflow.Structural.NormWM).
# 200805-10:00:58,515 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Functional.Normalization
# 200805-10:02:53,100 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Functional.Normalization".
# 200805-10:02:54,608 nipype.workflow INFO:
# 	 [Job 8] Completed (scaffoldflow.Functional.Normalization).
# 200805-10:02:54,616 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:02:54,669 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.Smoothing" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/Smoothing".
# 200805-10:02:54,669 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.CSFReg" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/CSFReg".
# 200805-10:02:54,669 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.WMReg" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/WMReg".
# 200805-10:02:54,674 nipype.workflow INFO:
# 	 [Node] Running "Smoothing" ("nipype.interfaces.spm.preprocess.Smooth")
# 200805-10:02:54,676 nipype.workflow INFO:
# 	 [Node] Running "WMReg" ("nipype.algorithms.confounds.CompCor")
# 200805-10:02:54,678 nipype.workflow INFO:
# 	 [Node] Running "CSFReg" ("nipype.algorithms.confounds.CompCor")
# 200805-10:02:56,610 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.38/13.98, Free processors: 5/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.WMReg
#                        * scaffoldflow.Denoising.CSFReg
#                        * scaffoldflow.Denoising.Smoothing
# /home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/algorithms/confounds.py:1099: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   betas = np.linalg.lstsq(X, data.T)[0]
# /home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/algorithms/confounds.py:1099: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   betas = np.linalg.lstsq(X, data.T)[0]
# 200805-10:14:58,910 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.CSFReg".
# 200805-10:15:25,630 nipype.workflow INFO:
# 	 [Job 14] Completed (scaffoldflow.Denoising.CSFReg).
# 200805-10:15:26,870 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.WMReg
#                        * scaffoldflow.Denoising.Smoothing
# 200805-10:15:21,298 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.WMReg".
# 200805-10:15:31,595 nipype.workflow INFO:
# 	 [Job 17] Completed (scaffoldflow.Denoising.WMReg).
# 200805-10:15:31,597 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.Smoothing
# 200805-10:15:33,597 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.DesignMat
#                        * scaffoldflow.Denoising.Smoothing
# 200805-10:15:40,787 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.DesignMat" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/DesignMat".
# 200805-10:16:01,649 nipype.workflow INFO:
# 	 [Node] Running "DesignMat" ("nipype.interfaces.utility.wrappers.Function")
# 200805-10:16:15,98 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.DesignMat".
# 200805-10:16:19,638 nipype.workflow INFO:
# 	 [Job 18] Completed (scaffoldflow.Denoising.DesignMat).
# 200805-10:16:19,766 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.Smoothing
# 200805-10:21:37,105 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.Smoothing".
# 200805-10:21:37,914 nipype.workflow INFO:
# 	 [Job 9] Completed (scaffoldflow.Denoising.Smoothing).
# 200805-10:21:37,940 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:21:39,917 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.GLM
# 200805-10:21:43,438 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.GLM" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/GLM".
# 200805-10:21:49,713 nipype.workflow INFO:
# 	 [Node] Running "GLM" ("nipype.interfaces.fsl.model.GLM"), a CommandLine Interface with command:
# fsl_glm -i /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/Smoothing/swrfunc_roi.nii -d /tmp/tmpmkvprt/DesMat.txt -o swrfunc_roi_glm.nii --demean --des_norm -m /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Structural/_subject_id_s8178/NormMask/wstruct_brain_mask.nii --out_res=glm_res.nii
# 200805-10:31:30,775 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.GLM".
# 200805-10:31:33,390 nipype.workflow INFO:
# 	 [Job 19] Completed (scaffoldflow.Denoising.GLM).
# 200805-10:31:33,565 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:31:35,394 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Denoising.BPF
# 200805-10:31:40,487 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Denoising.BPF" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/BPF".
# 200805-10:31:48,538 nipype.workflow INFO:
# 	 [Node] Running "BPF" ("nipype.interfaces.afni.preprocess.Bandpass"), a CommandLine Interface with command:
# 3dBandpass -prefix glm_res_bp.nii -dt 2.040000 0.008000 0.090000 /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/Denoising/_subject_id_s8178/BPF/glm_res.nii
# 200805-10:36:32,244 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.Denoising.BPF".
# 200805-10:36:33,638 nipype.workflow INFO:
# 	 [Job 20] Completed (scaffoldflow.Denoising.BPF).
# 200805-10:36:33,676 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:36:35,642 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 13.58/13.98, Free processors: 6/8.
#                      Currently running:
#                        * scaffoldflow.ROI_Time_Extraction
#                        * scaffoldflow.datasink
# 200805-10:36:41,585 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.ROI_Time_Extraction" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/_subject_id_s8178/ROI_Time_Extraction".
# 200805-10:36:43,621 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.datasink" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/_subject_id_s8178/datasink".
# 200805-10:37:00,127 nipype.workflow INFO:
# 	 [Node] Running "ROI_Time_Extraction" ("nipype.interfaces.utility.wrappers.Function")
# 200805-10:37:07,730 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 200805-10:37:10,337 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.datasink".
# 200805-10:37:11,665 nipype.workflow INFO:
# 	 [Job 21] Completed (scaffoldflow.datasink).
# 200805-10:37:11,667 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.ROI_Time_Extraction
# 200805-10:37:26,970 nipype.workflow INFO:
# 	 [Node] Finished "scaffoldflow.ROI_Time_Extraction".
# 200805-10:37:29,686 nipype.workflow INFO:
# 	 [Job 22] Completed (scaffoldflow.ROI_Time_Extraction).
# 200805-10:37:29,697 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:37:30,874 nipype.workflow INFO:
# 	 [Node] Setting-up "scaffoldflow.Tmp_File_Rmv" in "/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/_subject_id_s8178/Tmp_File_Rmv".
# 200805-10:37:31,715 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 13.78/13.98, Free processors: 7/8.
#                      Currently running:
#                        * scaffoldflow.Tmp_File_Rmv
# 200805-10:37:34,919 nipype.workflow INFO:
# 	 [Node] Running "Tmp_File_Rmv" ("nipype.interfaces.utility.wrappers.Function")
# 200805-10:37:36,4 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 200805-10:37:36,301 nipype.workflow WARNING:
# 	 [Node] Error on "scaffoldflow.Tmp_File_Rmv" (/media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/Mind_Blanking/data/Neuroimaging/Raw_data/scaffoldflow/_subject_id_s8178/Tmp_File_Rmv)
# 200805-10:37:38,28 nipype.workflow ERROR:
# 	 Node Tmp_File_Rmv.a0 failed to run on host udimed-H110M-R.
# 200805-10:37:38,50 nipype.workflow ERROR:
# 	 Saving crash info to /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Codes/python/crash-20200805-103738-sepehr-Tmp_File_Rmv.a0-896deb82-35ab-4bd6-bce6-d63edb51b0c8.pklz
# Traceback (most recent call last):
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 479, in run
#     result = self._run_interface(execute=True)
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 585, in _run_interface
#     return self._run_command(execute)
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/nodes.py", line 678, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/interfaces/base/core.py", line 382, in run
#     runtime = self._run_interface(runtime)
#   File "/home/sepehr/anaconda3/lib/python3.7/site-packages/nipype/interfaces/utility/wrappers.py", line 144, in _run_interface
#     out = function_handle(**args)
# TypeError: tmp_file_removal() got an unexpected keyword argument 'nodes'
# 200805-10:37:38,392 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 13.98/13.98, Free processors: 8/8.
# 200805-10:37:39,717 nipype.workflow INFO:
# 	 ***********************************
# 200805-10:37:39,719 nipype.workflow ERROR:
# 	 could not run node: scaffoldflow.Tmp_File_Rmv.a0
# 200805-10:37:39,721 nipype.workflow INFO:
# 	 crashfile: /media/sepehr/d504ddce-3b3c-4271-a3f5-2c6dd4c230f3/Projects/GITLAB/mind_blanking/Codes/python/crash-20200805-103738-sepehr-Tmp_File_Rmv.a0-896deb82-35ab-4bd6-bce6-d63edb51b0c8.pklz
# 200805-10:37:39,736 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-3e57ef4a0cac> in <module>
# ----> 1 res = scaffoldflow.run('MultiProc', plugin_args={'n_procs': 8})
#
# ~/anaconda3/lib/python3.7/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# ~/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     188
#     189         self._remove_node_dirs()
# --> 190         report_nodes_not_run(notrun)
#     191
#     192         # close any open resources
#
# ~/anaconda3/lib/python3.7/site-packages/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      93                 logger.debug(subnode._id)
#      94         logger.info("***********************************")
# ---> 95         raise RuntimeError(('Workflow did not execute cleanly. '
#      96                             'Check log for details'))
#      97
#
# RuntimeError: Workflow did not execute cleanly. Check log for details
